# %%
from sys import platform
import sys, os
# identification de la base de prix utilisée : directory principal
# sur ubuntu

path=''
if platform == 'linux' :
    path ='/workspace/NeuralPricing/A_GeneralizedSABR/CallOption'
# sur. mac osx
if platform == 'darwin' :
    path ='/Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc'
import keras,tensorflow,pkg_resources
dataDirectory='Data'
dataLearningFile = "1dim_VolLoc-Example-new.CSV"
dataNotationFile = "1dim_VolLoc-Example-new.CSV"
#datafile='Data/Baby_Learningbase1.CSV'
os.chdir(path)
# le package identifie la methode de calibration : sous-directory
# Out:
# /Users/olivier/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from __future__ import print_function
import tensorflow as tf
from math import sqrt, exp, log, erf,floor
import numpy 
import pandas
from decimal import *
import keras
from keras.layers import Dense
from keras.layers import Dropout
from keras import regularizers
from keras import callbacks
from keras.layers import Activation
from keras.layers import Lambda
from keras.models import Sequential
from keras.models import model_from_json
import keras.layers
import matplotlib
import matplotlib.pyplot as pyplot
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import mpl_toolkits
from mpl_toolkits.mplot3d import axes3d
from mpl_toolkits.mplot3d.axes3d import Axes3D
from sklearn import preprocessing
from sklearn import model_selection
import joblib
import seaborn as sns
import scipy
from IPython.display import display
import time
# %matplotlib inline
from IPython.display import display
from ipywidgets import interact, interactive, fixed, interact_manual,FloatProgress
import ipywidgets as widgets
import math

# %%
getcontext().prec = 8

from util_functions_YetiPhen_VolLoc import *

# %%
ListField1 ={"S1","mu1","bonus","YetiBarrier","YetiCoupon","PhoenixBarrier","PhoenixCoupon","PDIBarrier","PDIGearing","PDIStrike","PDIType",
             "maturity","nbDates"}

# %%
ListField2={"vol-date0-strike0","vol-date0-strike1","vol-date0-strike2","vol-date0-strike3","vol-date0-strike4","vol-date0-strike5","vol-date0-strike6",
           "vol-date0-strike7","vol-date0-strike8","vol-date0-strike9","vol-date0-strike10","vol-date0-strike11","vol-date0-strike12","vol-date0-strike13",
           "vol-date0-strike14","vol-date1-strike0","vol-date1-strike1","vol-date1-strike2","vol-date1-strike3","vol-date1-strike4","vol-date1-strike5",
           "vol-date1-strike6","vol-date1-strike7","vol-date1-strike8","vol-date1-strike9","vol-date1-strike10","vol-date1-strike11","vol-date1-strike12",
           "vol-date1-strike13","vol-date1-strike14","vol-date2-strike0","vol-date2-strike1","vol-date2-strike2","vol-date2-strike3","vol-date2-strike4",
           "vol-date2-strike5","vol-date2-strike6","vol-date2-strike7","vol-date2-strike8","vol-date2-strike9","vol-date2-strike10","vol-date2-strike11",
           "vol-date2-strike12","vol-date2-strike13","vol-date2-strike14","vol-date3-strike0","vol-date3-strike1","vol-date3-strike2","vol-date3-strike3",
           "vol-date3-strike4","vol-date3-strike5","vol-date3-strike6","vol-date3-strike7","vol-date3-strike8","vol-date3-strike9","vol-date3-strike10",
           "vol-date3-strike11","vol-date3-strike12","vol-date3-strike13","vol-date3-strike14","vol-date4-strike0","vol-date4-strike1","vol-date4-strike2",
           "vol-date4-strike3","vol-date4-strike4","vol-date4-strike5","vol-date4-strike6","vol-date4-strike7","vol-date4-strike8","vol-date4-strike9",
           "vol-date4-strike10","vol-date4-strike11","vol-date4-strike12","vol-date4-strike13","vol-date4-strike14","vol-date5-strike0","vol-date5-strike1",
           "vol-date5-strike2","vol-date5-strike3","vol-date5-strike4","vol-date5-strike5","vol-date5-strike6","vol-date5-strike7","vol-date5-strike8",
           "vol-date5-strike9","vol-date5-strike10","vol-date5-strike11","vol-date5-strike12","vol-date5-strike13","vol-date5-strike14","vol-date6-strike0",
           "vol-date6-strike1","vol-date6-strike2","vol-date6-strike3","vol-date6-strike4","vol-date6-strike5","vol-date6-strike6","vol-date6-strike7",
           "vol-date6-strike8","vol-date6-strike9","vol-date6-strike10","vol-date6-strike11","vol-date6-strike12","vol-date6-strike13","vol-date6-strike14",
           "vol-date7-strike0","vol-date7-strike1","vol-date7-strike2","vol-date7-strike3","vol-date7-strike4","vol-date7-strike5","vol-date7-strike6",
           "vol-date7-strike7","vol-date7-strike8","vol-date7-strike9","vol-date7-strike10","vol-date7-strike11","vol-date7-strike12","vol-date7-strike13",
           "vol-date7-strike14","vol-date8-strike0","vol-date8-strike1","vol-date8-strike2","vol-date8-strike3","vol-date8-strike4","vol-date8-strike5",
           "vol-date8-strike6","vol-date8-strike7","vol-date8-strike8","vol-date8-strike9","vol-date8-strike10","vol-date8-strike11","vol-date8-strike12",
           "vol-date8-strike13","vol-date8-strike14","vol-date9-strike0","vol-date9-strike1","vol-date9-strike2","vol-date9-strike3","vol-date9-strike4",
           "vol-date9-strike5","vol-date9-strike6","vol-date9-strike7","vol-date9-strike8","vol-date9-strike9","vol-date9-strike10","vol-date9-strike11",
           "vol-date9-strike12","vol-date9-strike13","vol-date9-strike14","vol-date10-strike0","vol-date10-strike1","vol-date10-strike2","vol-date10-strike3",
           "vol-date10-strike4","vol-date10-strike5","vol-date10-strike6","vol-date10-strike7","vol-date10-strike8","vol-date10-strike9","vol-date10-strike10",
           "vol-date10-strike11","vol-date10-strike12","vol-date10-strike13","vol-date10-strike14","vol-date11-strike0","vol-date11-strike1","vol-date11-strike2",
           "vol-date11-strike3","vol-date11-strike4","vol-date11-strike5","vol-date11-strike6","vol-date11-strike7",
           "vol-date11-strike8","vol-date11-strike9","vol-date11-strike10","vol-date11-strike11","vol-date11-strike12","vol-date11-strike13","vol-date11-strike14"}

# %%
params=metaparameters()

params.INPUT_DIM  = 193
params.INPUT_OPTION = 193
params.INPUT_VOL =13
params.NB_NEURON_PRINCIPAL =8
params.ACTIVATION_PRINCIPALE = 'tanh'
params.ACTIVATION_PRINCIPALE_FINALE = 'linear'
params.INITIAL_LEARNING_NB_EPOCH=1000
params.LEARNINGBASE_ORIGIN="New_Test"
params.LEARNINGBASE_BUT="New_Simu_Test"
params.GENETIC_LEARNING_NB_EPOCH = 10
params.BATCH_SIZE_PRINCIPAL = 32768
params.OPTIMIZER='adamax'
params.OPTIMIZER_GENETIC='SGD'
params.NBLAYERS = 11
params.NB_LOOPS = 5
params.PATH = path
params.VERBOSE_FLAG=2
params.EPSILON_GREEDINESS = 0.25
params.EPSILON_GREEDINESS_DECREASING_FACTOR = 0.99
params.INITIAL_NETWORK_STRUCTURE = [[0,10],[1,20],[2,30],[0,10]]
params.NOTATION_FILE = dataDirectory+'/'+dataNotationFile
params.LISTFIELD1=ListField1
params.LISTFIELD2=ListField2

# %%
startTime = time.time()
dataframe = pandas.read_csv(dataDirectory+"/"+dataLearningFile)
endTime = time.time()
print('temps de lecture du ficher',endTime - startTime)
X = dataframe[ListField1.union(ListField2)];
Y_Vol = dataframe['price'];
datasize=X.size
X_scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
X_scaled = (X_scaler.fit_transform(X))
params.X_scaler = X_scaler
params.X_scaled = X_scaled
params.X = X
Y_scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
Y_scaled = (Y_scaler.fit_transform(np.array(Y_Vol).reshape(-1, 1))).reshape(1, -1)[0]
params.Y_scaler = Y_scaler
params.Y_scaled = Y_scaled
params.Y_Vol = Y_Vol

startTime = time.time()
dataframe = pandas.read_csv(dataDirectory+"/"+dataNotationFile)
endTime = time.time()
print('temps de lecture du ficher',endTime - startTime)
X = dataframe[ListField1.union(ListField2)];
Y_Vol = dataframe['price'];
datasize=X.size
X_scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
X_scaled = (X_scaler.fit_transform(X))
params.X_Notation_scaler = X_scaler
params.X_Notation_scaled = X_scaled
params.X_Notation = X
Y_scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
Y_scaled = (Y_scaler.fit_transform(np.array(Y_Vol).reshape(-1, 1))).reshape(1, -1)[0]
params.Y_Notation_scaler = Y_scaler
params.Y_Notation_scaled = Y_scaled
params.Y_Notation_Vol = Y_Vol
# Out:
# temps de lecture du ficher 0.042085886001586914
# temps de lecture du ficher 0.03880882263183594

# %%
#Y_ordre1_Vol,model_Initial,y_scaler_Vol,y_scaled_Vol=InitialCalibration2(params.Y_Vol,"Vol",params)

# %%
#nbloop =10
#pkgNameOriginal = params.LEARNINGBASE_ORIGIN
#pkgNameBut = params.LEARNINGBASE_BUT
#Y_ordre1,model2,y_scaler,y_scaled,resultats=ReinforceOptimality2(pkgNameOriginal,pkgNameBut,nbloop,"Vol",params)

# %% [markdown]
# # Test des Modules d'Injection

# %%
speclist =[[0,10],[1,20],[0,30],[0,10]]
mm =buidModel(speclist,params)
print(mm.summary())
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0919 18:53:05.803141 4516292032 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0919 18:53:05.818220 4516292032 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0919 18:53:05.821786 4516292032 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 193)          0
# __________________________________________________________________________________________________
# Layer0 (Dense)                  (None, 10)           1940        input_1[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_type11 (Dense)      (None, 20)           220         Layer0[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_Multiplier1 (Dense) (None, 10)           200         ResnetLayer_type11[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 10)           0           ResnetLayer_Multiplier1[0][0]
#                                                                  Layer0[0][0]
# __________________________________________________________________________________________________
# Layer2 (Dense)                  (None, 30)           330         add_1[0][0]
# __________________________________________________________________________________________________
# Layer3 (Dense)                  (None, 10)           310         Layer2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            11          Layer3[0][0]
# ==================================================================================================
# Total params: 3,011
# Trainable params: 3,011
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
speclist =[[0,10],[2,20],[0,30],[0,10]]
mm =buidModel(speclist,params)
print(mm.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 193)          0
# __________________________________________________________________________________________________
# Layer0 (Dense)                  (None, 10)           1940        input_2[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_type21 (Dense)      (None, 20)           220         Layer0[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_Multiplier1 (Dense) (None, 20)           200         Layer0[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 20)           0           ResnetLayer_type21[0][0]
#                                                                  ResnetLayer_Multiplier1[0][0]
# __________________________________________________________________________________________________
# Layer2 (Dense)                  (None, 30)           630         add_2[0][0]
# __________________________________________________________________________________________________
# Layer3 (Dense)                  (None, 10)           310         Layer2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            11          Layer3[0][0]
# ==================================================================================================
# Total params: 3,311
# Trainable params: 3,311
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
mm =buidModel(specList,params)
deltaNbNeuronList= [13, 5, 2, 1]
mm1 =injectionModel(mm,specList,deltaNbNeuronList,params) 
print(mm1.summary())
# Out:
# W0919 18:53:07.874545 4516292032 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0919 18:53:07.875508 4516292032 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0919 18:53:07.995541 4516292032 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# (193, 10) (193, 23) (193, 10)
# (10,) (23,) (10,)
# (10, 20) (23, 25) (10, 20)
# (20,) (25,) (20,)
# (20, 10) (25, 23) (20, 10)
# (10, 30) (23, 32) (10, 30)
# (30,) (32,) (30,)
# (10, 30) (23, 32) (10, 30)
# (30, 10) (32, 11) (30, 10)
# (10,) (11,) (10,)
# (10, 1) (11, 1) (10, 1)
# (1,) (1,) (1,)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 193)          0
# __________________________________________________________________________________________________
# Layer0 (Dense)                  (None, 23)           4462        input_4[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_type11 (Dense)      (None, 25)           600         Layer0[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_Multiplier1 (Dense) (None, 23)           575         ResnetLayer_type11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 23)           0           ResnetLayer_Multiplier1[0][0]
#                                                                  Layer0[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_type22 (Dense)      (None, 32)           768         add_5[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_Multiplier2 (Dense) (None, 32)           736         add_5[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32)           0           ResnetLayer_type22[0][0]
#                                                                  ResnetLayer_Multiplier2[0][0]
# __________________________________________________________________________________________________
# Layer3 (Dense)                  (None, 11)           363         add_6[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            12          Layer3[0][0]
# ==================================================================================================
# Total params: 7,516
# Trainable params: 7,516
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
cnfigName="Vol"
pkgPath="New_Test"
loaded_model,X_scaler_loaded,y_scaler_loaded,y_scaled_loaded,Y_ordre1_loaded,loaded_speclist = reloadModel(cnfigName,pkgPath)

# %%
deltaspecList=[0,10,0,0]
mm1 =injectionModel(loaded_model,loaded_speclist,deltaspecList,params) 
##print(mm1.summary())
Compute_Note(loaded_model,params)
Compute_Note(mm1,params);
# Out:
# (193, 10) (193, 10) (193, 10)
# (10,) (10,) (10,)
# (10, 20) (10, 30) (10, 20)
# (20,) (30,) (20,)
# (20, 10) (30, 10) (20, 10)
# (10, 30) (10, 30) (10, 30)
# (30,) (30,) (30,)
# (10, 30) (10, 30) (10, 30)
# (30, 10) (30, 10) (30, 10)
# (10,) (10,) (10,)
# (10, 1) (10, 1) (10, 1)
# (1,) (1,) (1,)
# Note = 5.069347437601359
# Note = 5.069347140463607

# %%
ResnetRank=2
ResnetWeight=35
ResnetType=1
mm2=injectionModelWithInsertion(loaded_model,loaded_speclist,ResnetRank,ResnetWeight,ResnetType,params)
##print(mm2.summary())
Compute_Note(loaded_model,params)
Compute_Note(mm2,params);
# Out:
# (193, 10) (193, 10) (193, 10)
# (10,) (10,) (10,)
# (10, 20) (10, 20) (10, 20)
# (20,) (20,) (20,)
# (20, 10) (20, 10) (20, 10)
# (10, 30) (10, 30) (10, 30)
# (30,) (30,) (30,)
# (10, 30) (10, 30) (10, 30)
# (30, 10) (30, 10) (30, 10)
# (10,) (10,) (10,)
# (10, 1) (10, 1) (10, 1)
# (1,) (1,) (1,)
# Note = 5.069347437601359
# Note = 5.069347437601359

# %%
def injectionModelWithInsertion2(model,modelspecList,ResnetRank,ResnetWeight,ResnetType,params) : 
    modelspeclist2 = copy.deepcopy(modelspecList)
    modelspeclist2.insert(ResnetRank,[ResnetType,ResnetWeight])
    model2 = buidModel(modelspeclist2,params)   
    ## debut de la recopie des poids
    if platform == 'linux' :
    # make the model parallel
        G = 4
        model2 =keras.utils.multi_gpu_model(model2, gpus=G)
    if (params.OPTIMIZER_GENETIC == 'SGD') :
        sgd = keras.optimizers.SGD(lr=0.01,decay = 1e-6)
        model2.compile(loss='mse', optimizer=sgd, metrics=["accuracy"])
    else : 
        model2.compile(loss='mse', optimizer='adamax', metrics=["accuracy"])   
    weights1=model.get_weights()
    param_list1 = list(map(lambda k: k.shape ,weights1))
    weights2=model2.get_weights()
    param_list2 = list(map(lambda k: k.shape ,weights2))
    print("param_list1=",param_list1," param_list2=",param_list2)
    paramInsertDebut = ComputeparamInsertDebut(modelspecList,ResnetRank)
    print("paramInsertDebut=",paramInsertDebut)
    gapRank =ResnetWidth(ResnetType)
    paramInsertFin = paramInsertDebut + gapRank
    firstset=[param_list1[i] for i in range(paramInsertDebut)]
    lastset=[param_list1[i] for i in range(paramInsertFin,len(param_list1))]
  ## debut de la recopie des poids
    for iparam in range(paramInsertDebut):
        w = subcopy(weights1[iparam],weights2[iparam],param_list1[iparam])
        weights2[iparam] = w
    for iparam in range(paramInsertDebut,len(param_list1)):
        w = subcopy2(weights1[iparam],weights2[iparam+gapRank],param_list2[iparam+gapRank])
        weights2[iparam+gapRank] = w
    for j in range(gapRank)  :  
        if (len(param_list2[paramInsertDebut+j]) == 2):
            weights2[paramInsertDebut+j][0:param_list2[paramInsertDebut+j][0],0:param_list2[paramInsertDebut+j][1]] = 0
        else :
            weights2[paramInsertDebut+j][0:param_list2[paramInsertDebut+j][0]] = 0
    if platform == 'linux' :
    # make the model parallel
        G = 4
        model2 =keras.utils.multi_gpu_model(model2, gpus=G)
    if (params.OPTIMIZER_GENETIC == 'SGD') :
        sgd = keras.optimizers.SGD(lr=0.01,decay = 1e-6)
        model2.compile(loss='mse', optimizer=sgd, metrics=["accuracy"])
    else : 
        model2.compile(loss='mse', optimizer='adamax', metrics=["accuracy"])
    model2.set_weights(weights2)    
    return model2

# %%
def subcopy2(w1,w2,dims):
    print(w1.shape,w2.shape,dims)
    if(len(dims) == 1):
        w2[0:dims[0]] = w1[0:dims[0]]
        w2[dims[0]:w2.shape[0]] = 0
    if(len(dims) == 2):
        w2[0:dims[0],0:dims[1]] = w1[0:dims[0],0:dims[1]]
        w2[dims[0]:w2.shape[0],0:dims[1]] =0
        w2[0:dims[0],dims[1]:w2.shape[1]] = 0
    return w2

# %%
ResnetRank=1
ResnetWeight=35
ResnetType=2
specList= [[0, 10],  [0, 10]]
mm =buidModel(specList,params)
mm2=injectionModelWithInsertion2(mm,specList,ResnetRank,ResnetWeight,ResnetType,params)
#print(mm2.summary())
Compute_Note(loaded_model,params)
Compute_Note(mm2,params);
# Out:
# param_list1= [(193, 10), (10,), (10, 10), (10,), (10, 1), (1,)]  param_list2= [(193, 10), (10,), (10, 35), (35,), (10, 35), (35, 10), (10,), (10, 1), (1,)]
# paramInsertDebut= 2
# (193, 10) (193, 10) (193, 10)
# (10,) (10,) (10,)
# (10, 10) (35, 10) (35, 10)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-d0cbe92d6b32> in <module>()
#       4 specList= [[0, 10],  [0, 10]]
#       5 mm =buidModel(specList,params)
# ----> 6 mm2=injectionModelWithInsertion2(mm,specList,ResnetRank,ResnetWeight,ResnetType,params)
#       7 #print(mm2.summary())
#       8 Compute_Note(loaded_model,params)
#
# <ipython-input-33-83884128f592> in injectionModelWithInsertion2(model, modelspecList, ResnetRank, ResnetWeight, ResnetType, params)
#      29         weights2[iparam] = w
#      30     for iparam in range(paramInsertDebut,len(param_list1)):
# ---> 31         w = subcopy2(weights1[iparam],weights2[iparam+gapRank],param_list2[iparam+gapRank])
#      32         weights2[iparam+gapRank] = w
#      33     for j in range(gapRank)  :
#
# <ipython-input-19-05c23866d766> in subcopy2(w1, w2, dims)
#       5         w2[dims[0]:w2.shape[0]] = 0
#       6     if(len(dims) == 2):
# ----> 7         w2[0:dims[0],0:dims[1]] = w1[0:dims[0],0:dims[1]]
#       8         w2[dims[0]:w2.shape[0],0:dims[1]] =0
#       9         w2[0:dims[0],dims[1]:w2.shape[1]] = 0
#
# ValueError: could not broadcast input array from shape (10,10) into shape (35,10)

# %%
def buildParamList(modelspecList,params) : 
    model = buidModel(modelspecList,params)   
    weights1=model.get_weights()
    return list(map(lambda k: k.shape ,weights1))

# %%
def CountIndividuals(a)    :
    ii=0
    for f in os.listdir(a):
        ii=ii+1
    return ii

# %%
def convergeIndividualModel(model,params):
    print('convergeIndividualModel :')
    model.compile(loss='mse', optimizer='SGD', metrics=["accuracy"])
    X_train, X_test, y_train, y_test = model_selection.train_test_split( \
            params.X_scaled, params.Y_scaled, test_size=0.10, random_state=3)
    checkpointer = keras.callbacks.ModelCheckpoint(filepath = "BestWeights.hdf5",verbose=1,\
                                                   save_best_only=True , monitor = 'loss')
    numpy.random.seed(3)
    model.fit(X_train, y_train, epochs=params.GENETIC_LEARNING_NB_EPOCH, batch_size=params.BATCH_SIZE_PRINCIPAL,\
              verbose=params.VERBOSE_FLAG, shuffle = True, callbacks=[checkpointer])

# %%
def ComputeBestNoteIndexlist(ListOfnote,populationctrlFunc,iTimeStep):
    lenlist = len(ListOfnote)
    sortedlist = np.argsort(ListOfnote)
    lim = populationctrlFunc(iTimeStep)
    lim = min(lenlist,lim)
    print('lim=',lim)
    ListOfWorst=sortedlist[lim:] 
    ListOfBest=sortedlist[:lim]
    return ListOfWorst,ListOfBest

# %%
def pathCreatechild(TimePath,individualpath,child):
    pathCreated = TimePath + '/individu' +  str(child)
    if not(os.path.isdir(pathCreated)):
                os.makedirs(pathCreated,0o777 )
    print('pathCreatechild=',pathCreated)
    return pathCreated

# %%
def killIndividual(individualPath):
    print("killing :",individualPath)
    shutil.rmtree(individualPath)

# %%
def saveIndividualModel(model,X_scaler,y_scaler,y_scaled,Y_ordre1,specList,path,cnfigName):
    model.save_weights(path + '/' + cnfigName +'.hdf5')
    # save model to JSON
    model_json = model.to_json()
    with open(path + '/' + cnfigName +'.json', 'w') as json_file:
        json_file.write(model_json)
    # Save scaler Xand Y
    filename = path + '/' + cnfigName +'scalerX.pkl'
    _= joblib.dump(X_scaler , filename , compress = 9)
    filename = path + '/' + cnfigName +'scalerY.pkl'
    _= joblib.dump(y_scaler , filename , compress = 9)
    filename = path + '/' + cnfigName +'scaledY.pkl'
    _= joblib.dump(y_scaled , filename , compress = 9)
    filename = path + '/' + cnfigName +'Y_ordre1.res'
    _= joblib.dump(Y_ordre1 , filename , compress = 9)
    filename = path + '/' + cnfigName +'current_structure.str'
    _= joblib.dump(specList , filename , compress = 9)
    print('saveIndividualModel model2 at :',path)

# %%
def loadInvidualModel(IndividuPath,cnfigName):
    json_file = open(IndividuPath+ "/"+ cnfigName  +'.json', 'r')
    file = IndividuPath+ '/' + cnfigName  +'.json'
    
    loaded_model_json = json_file.read()
    json_file.close()  
    loaded_model = model_from_json(loaded_model_json)           
    filename2 = IndividuPath+ '/' + cnfigName  +'current_structure.str'
    specList = joblib.load(filename2 )
    filename2 = IndividuPath+ '/' + cnfigName  +'scalerY.pkl'
    y_scaler = joblib.load(filename2)
    filename2 = IndividuPath+ '/' + cnfigName  +'scaledY.pkl'
    y_scaled = joblib.load(filename2)
    print('loadInvidualModel :IndividuPath=',IndividuPath)
    return loaded_model, specList,y_scaler,y_scaled

# %%
def BulleListPar(i,NbLayers):
    return [floor(exp(2.5-2*abs(x-i)/(0.5*NbLayers)))+1 for x in range(NbLayers)]

# %%
BulleListPar(0,11)
# Out:
# [13, 9, 6, 5, 3, 2, 2, 1, 1, 1, 1]

# %%
def mutateIndividualModel(model,specList,params):
    NbLayers = len(specList)
    deltaNbNeuronList = BulleListPar(0,NbLayers)
    print('mutateIndividualModel : adding neurons',deltaNbNeuronList)
    print('specList=',specList)
    print('deltaNbNeuronList=',deltaNbNeuronList)
    model2 =injectionModel(model,specList,deltaNbNeuronList,params) 
    specList2 = [[specList[i][0],specList[i][1]+  deltaNbNeuronList[i] ] for i in range(NbLayers)]
    
    return model2,specList2

# %%
def copyModelFromInitial(originalModelPath,IndividuPath):
    shutil.copyfile(originalModelPath+'current_structure.str',IndividuPath+'current_structure.str')
    shutil.copyfile(originalModelPath+'scalerY.pkl',IndividuPath+'scalerY.pkl')
    shutil.copyfile(originalModelPath+'scaledY.pkl',IndividuPath+'scaledY.pkl')

# %%
def createResidues(X,X_scaler,model,y_scaler,Ycall,generate_errors):
    Y_size = X.shape[0]
    print("creating the residus for the boosting")
    Y_ordre1=numpy.zeros(Ycall.size); 
    if (generate_errors):        
        for i in range(Y_size):
            normalizedData=X_scaler.transform(X[i].reshape(1, -1))
            normalizedPrediction=model.predict(normalizedData)
            outputData=y_scaler.inverse_transform(normalizedPrediction)
            Y_ordre1[i]=outputData[0,0]-Ycall[i]
        return Y_ordre1
    else:
        return Y_ordre1

# %%
def ComputeIndividualNote(individualpath,cnfigName,params):
    file = individualpath+'/' +cnfigName +'.json'
    os.chdir(individualpath)
    json_file = open(file, 'r')
    loaded_model_json = json_file.read()
    json_file.close()              
    model = model_from_json(loaded_model_json)              ### chargment du model initial (1)
    file = individualpath +'/'+cnfigName +'.hdf5'
    model.load_weights(file)  ### chargment du model initial (2)
    note = Compute_Note(model,params)
    return note

# %%
def Idealpopulation(nstep):
    if (nstep<4): 
        return 3*nstep+2
    else:
        return 20

# %%
def ReinforceOptimalityWithGenetic(pkgNameOriginal,pkgNameBut,InitialNbIndividual,populationctrlFunc,nbChildAllowed,\
                         nbloop,Ycall,cnfigName,params,save=True,generate_errors = False):
    originalModelPath=params.PATH + "/" + pkgNameOriginal   
    filename = originalModelPath + '/' + cnfigName +'scaledY.pkl'
    y_scaled = joblib.load(filename)
    filename = originalModelPath + '/' + cnfigName +'scalerY.pkl'
    y_scaler = joblib.load(filename)
    X_train, X_test, y_train, y_test = model_selection.train_test_split( \
                params.X_scaled, y_scaled, test_size=0.10, random_state=3)
    SimuPath = params.PATH + "/" + pkgNameBut 
    if not(os.path.isdir(SimuPath)):
        os.makedirs(SimuPath,0o777 )
    SimuPath = SimuPath + '/loop'
    if (os.path.isdir(SimuPath)):
        shutil.rmtree(SimuPath)
    os.makedirs(SimuPath,0o777 ) 
    precedingIndividualPathList =[]
    for iTimeStep in range(nbloop):
        TimePath = SimuPath + "/" + "time"+str(iTimeStep) 
        if not(os.path.isdir(TimePath)):
                os.makedirs(TimePath,0o777 )
                print("created : ",TimePath)
        if (iTimeStep == 0) :
            for individual in range(InitialNbIndividual):
                IndividuPath= TimePath +  "/individu" + str(individual)
                if not(os.path.isdir(IndividuPath)):
                        os.makedirs(IndividuPath,0o777 )
                        print("created : ",IndividuPath)
                ## ....traitement
                model,specList,y_scaler,y_scaled = loadInvidualModel(originalModelPath,cnfigName)
                model2,specList2=mutateIndividualModel(model,specList,params)
                convergeIndividualModel(model2,params)
                Y_ordre1 = createResidues(params.X,X_scaler,model2,y_scaler,Ycall,generate_errors)
                saveIndividualModel(model2,X_scaler,y_scaler,y_scaled,Y_ordre1,specList,IndividuPath,cnfigName)   
                ## .. Fin du traitement
                precedingIndividualPathList.append(IndividuPath)                     
        else :
            invidualpathList = []
            individuNumero =0
            for individualpath in precedingIndividualPathList:                            
            ## ....traitement
                model,specList,y_scaler,y_scaled = loadInvidualModel(individualpath,cnfigName)
                for child in range(nbChildAllowed): 
                    childPath = pathCreatechild(TimePath,individualpath,individuNumero)
                    individuNumero +=1
                    model2,specList2=mutateIndividualModel(model,specList,params)
                    convergeIndividualModel(model2,params)
                    Y_ordre1 = createResidues(params.X,X_scaler,model2,y_scaler,Ycall,generate_errors)
                    saveIndividualModel(model2,X_scaler,y_scaler,y_scaled,Y_ordre1,specList2,childPath,cnfigName)
                    invidualpathList.append(childPath)
                precedingIndividualPathList = invidualpathList
            ## .. Fin du traitement
        ## .. Debut Selection Naturelle
        ListOnote =[]
        invidualpathList = precedingIndividualPathList
        for individualpath in invidualpathList :
            note = ComputeIndividualNote(individualpath,cnfigName,params)
            ListOnote.append(note)
        worstNoteIndexlist,bestNoteIndexlist = ComputeBestNoteIndexlist(ListOnote,populationctrlFunc,iTimeStep)
        print('ListOnote=',ListOnote)
        print('bestNoteIndexlist=',bestNoteIndexlist)
        print('worstNoteIndexlist=',worstNoteIndexlist)
        for index in worstNoteIndexlist : 
            killIndividual(invidualpathList[index])
        precedingIndividualPathList = [invidualpathList[index] for index in bestNoteIndexlist]

# %%
nbloop =5;NbIndividual =3; nbChildAllowed =4
pkgNameOriginal = params.LEARNINGBASE_ORIGIN
pkgNameBut = params.LEARNINGBASE_BUT
InitialNbIndividual =3;naturalSelectionPercentage =0.5
a=ReinforceOptimalityWithGenetic(pkgNameOriginal,pkgNameBut,InitialNbIndividual,Idealpopulation,nbChildAllowed,\
                       nbloop,Y_Vol,"Vol",params)
# Out:
# created :  /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0
# created :  /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu0
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Test
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# W0917 17:22:51.216933 4645426624 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 0.1613 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.16130, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0729 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.16130 to 0.07285, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0361 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.07285 to 0.03606, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0283 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.03606 to 0.02831, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0262 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.02831 to 0.02616, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0251 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.02616 to 0.02514, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0243 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.02514 to 0.02435, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0236 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.02435 to 0.02362, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0229 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.02362 to 0.02294, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0223 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.02294 to 0.02230, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu0
# created :  /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu1
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Test
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 1.3741 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 1.37405, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.1384 - acc: 0.0011
#
# Epoch 00002: loss improved from 1.37405 to 0.13842, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0416 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.13842 to 0.04163, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0203 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.04163 to 0.02030, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0136 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.02030 to 0.01362, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0113 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01362 to 0.01128, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0104 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01128 to 0.01038, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0100 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01038 to 0.00998, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0097 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.00998 to 0.00975, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0096 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.00975 to 0.00958, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu1
# created :  /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu2
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Test
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 1.3741 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 1.37405, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.1384 - acc: 0.0011
#
# Epoch 00002: loss improved from 1.37405 to 0.13842, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0416 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.13842 to 0.04163, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0203 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.04163 to 0.02033, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0136 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.02033 to 0.01363, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0113 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01363 to 0.01129, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0104 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01129 to 0.01039, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0100 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01039 to 0.00998, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0097 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.00998 to 0.00975, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0096 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.00975 to 0.00959, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu2
# Note = 17.20655028602462
# Note = 12.343552699794602
# Note = 12.343869158969774
# lim= 2
# ListOnote= [17.20655028602462, 12.343552699794602, 12.343869158969774]
# bestNoteIndexlist= [1 2]
# worstNoteIndexlist= [0]
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu0
# created :  /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu1
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu0
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 1.4088 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 1.40882, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0255 - acc: 0.0000e+00
#
# Epoch 00002: loss improved from 1.40882 to 0.02549, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0214 - acc: 0.0000e+00
#
# Epoch 00003: loss improved from 0.02549 to 0.02139, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0200 - acc: 0.0000e+00
#
# Epoch 00004: loss improved from 0.02139 to 0.02004, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0192 - acc: 0.0000e+00
#
# Epoch 00005: loss improved from 0.02004 to 0.01918, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0185 - acc: 0.0000e+00
#
# Epoch 00006: loss improved from 0.01918 to 0.01848, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0179 - acc: 0.0000e+00
#
# Epoch 00007: loss improved from 0.01848 to 0.01789, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0174 - acc: 0.0000e+00
#
# Epoch 00008: loss improved from 0.01789 to 0.01738, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0169 - acc: 0.0000e+00
#
# Epoch 00009: loss improved from 0.01738 to 0.01695, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0166 - acc: 0.0000e+00
#
# Epoch 00010: loss improved from 0.01695 to 0.01657, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu0
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu1
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 1.4088 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 1.40882, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0240 - acc: 0.0000e+00
#
# Epoch 00002: loss improved from 1.40882 to 0.02402, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0210 - acc: 0.0000e+00
#
# Epoch 00003: loss improved from 0.02402 to 0.02098, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0199 - acc: 0.0000e+00
# Epoch 00004: loss improved from 0.02098 to 0.01988, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0191 - acc: 0.0000e+00
#
# Epoch 00005: loss improved from 0.01988 to 0.01911, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0185 - acc: 0.0000e+00
#
# Epoch 00006: loss improved from 0.01911 to 0.01846, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0179 - acc: 0.0000e+00
#
# Epoch 00007: loss improved from 0.01846 to 0.01791, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0174 - acc: 0.0000e+00
#
# Epoch 00008: loss improved from 0.01791 to 0.01743, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0170 - acc: 0.0000e+00
#
# Epoch 00009: loss improved from 0.01743 to 0.01702, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0167 - acc: 0.0000e+00
#
# Epoch 00010: loss improved from 0.01702 to 0.01665, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu1
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu2
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 1.4088 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 1.40882, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0252 - acc: 0.0000e+00
#
# Epoch 00002: loss improved from 1.40882 to 0.02517, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0213 - acc: 0.0000e+00
#
# Epoch 00003: loss improved from 0.02517 to 0.02127, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0200 - acc: 0.0000e+00
#
# Epoch 00004: loss improved from 0.02127 to 0.01996, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0191 - acc: 0.0000e+00
#
# Epoch 00005: loss improved from 0.01996 to 0.01911, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0184 - acc: 0.0000e+00
#
# Epoch 00006: loss improved from 0.01911 to 0.01842, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0178 - acc: 0.0000e+00
#
# Epoch 00007: loss improved from 0.01842 to 0.01783, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0173 - acc: 0.0000e+00
#
# Epoch 00008: loss improved from 0.01783 to 0.01733, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0169 - acc: 0.0000e+00
#
# Epoch 00009: loss improved from 0.01733 to 0.01690, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0165 - acc: 0.0000e+00
#
# Epoch 00010: loss improved from 0.01690 to 0.01653, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu2
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu3
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 1.4088 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 1.40882, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0255 - acc: 0.0000e+00
#
# Epoch 00002: loss improved from 1.40882 to 0.02549, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0214 - acc: 0.0000e+00
#
# Epoch 00003: loss improved from 0.02549 to 0.02140, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0200 - acc: 0.0000e+00
#
# Epoch 00004: loss improved from 0.02140 to 0.02004, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0192 - acc: 0.0000e+00
#
# Epoch 00005: loss improved from 0.02004 to 0.01918, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0185 - acc: 0.0000e+00
#
# Epoch 00006: loss improved from 0.01918 to 0.01848, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0179 - acc: 0.0000e+00
#
# Epoch 00007: loss improved from 0.01848 to 0.01789, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0174 - acc: 0.0000e+00
#
# Epoch 00008: loss improved from 0.01789 to 0.01738, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0169 - acc: 0.0000e+00
#
# Epoch 00009: loss improved from 0.01738 to 0.01695, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0166 - acc: 0.0000e+00
#
# Epoch 00010: loss improved from 0.01695 to 0.01657, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu3
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu2
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu4
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0609 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06092, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0183 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06092 to 0.01828, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01828 to 0.01440, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01440 to 0.01411, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0139 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01411 to 0.01394, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01394 to 0.01379, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0136 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01379 to 0.01364, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01364 to 0.01349, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0133 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01349 to 0.01335, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu4
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu5
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0603 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06032, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0181 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06032 to 0.01807, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01807 to 0.01441, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01441 to 0.01413, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0140 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01413 to 0.01396, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01396 to 0.01381, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0137 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01381 to 0.01365, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01365 to 0.01351, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0134 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01351 to 0.01336, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu5
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu6
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0603 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06032, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0181 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06032 to 0.01807, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01807 to 0.01441, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01441 to 0.01413, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0140 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01413 to 0.01396, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01396 to 0.01381, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0137 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01381 to 0.01365, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01365 to 0.01351, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0134 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01351 to 0.01336, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu6
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu7
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0609 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06092, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0182 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06092 to 0.01820, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01820 to 0.01440, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01440 to 0.01411, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0139 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01411 to 0.01395, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01395 to 0.01379, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0136 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01379 to 0.01364, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01364 to 0.01349, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0133 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01349 to 0.01335, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu7
# Note = 25.104655342340884
# Note = 25.521783507765193
# Note = 25.2025458932461
# Note = 25.104311932963586
# Note = 71.72879619713831
# Note = 71.7339634881095
# Note = 71.73406047516372
# Note = 71.73502823947237
# lim= 5
# ListOnote= [25.104655342340884, 25.521783507765193, 25.2025458932461, 25.104311932963586, 71.72879619713831, 71.7339634881095, 71.73406047516372, 71.73502823947237]
# bestNoteIndexlist= [3 0 2 1 4]
# worstNoteIndexlist= [5 6 7]
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu5
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu6
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu7
# created :  /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu3
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu0
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4218 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.42179, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.7199 - acc: 0.0000e+00
#
# Epoch 00002: loss did not improve from 0.42179
# Epoch 3/10
#  - 0s - loss: 1.6952 - acc: 0.0011
#
# Epoch 00003: loss did not improve from 0.42179
# Epoch 4/10
#  - 0s - loss: 0.6148 - acc: 0.0011
#
# Epoch 00004: loss did not improve from 0.42179
# Epoch 5/10
#  - 0s - loss: 0.2148 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.42179 to 0.21478, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0549 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.21478 to 0.05488, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0303 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.05488 to 0.03029, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0260 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.03029 to 0.02598, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0249 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.02598 to 0.02492, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0243 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.02492 to 0.02426, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu0
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu1
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4218 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.42179, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.7116 - acc: 0.0000e+00
#
# Epoch 00002: loss did not improve from 0.42179
# Epoch 3/10
#  - 0s - loss: 1.6843 - acc: 0.0011
#
# Epoch 00003: loss did not improve from 0.42179
# Epoch 4/10
#  - 0s - loss: 0.6945 - acc: 0.0011
#
# Epoch 00004: loss did not improve from 0.42179
# Epoch 5/10
#  - 0s - loss: 0.2144 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.42179 to 0.21441, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0526 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.21441 to 0.05255, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0290 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.05255 to 0.02898, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0252 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.02898 to 0.02518, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0243 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.02518 to 0.02425, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0236 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.02425 to 0.02364, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu1
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu2
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4218 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.42179, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.7116 - acc: 0.0000e+00
#
# Epoch 00002: loss did not improve from 0.42179
# Epoch 3/10
#  - 0s - loss: 1.6843 - acc: 0.0011
#
# Epoch 00003: loss did not improve from 0.42179
# Epoch 4/10
#  - 0s - loss: 0.6228 - acc: 0.0011
#
# Epoch 00004: loss did not improve from 0.42179
# Epoch 5/10
#  - 0s - loss: 0.2127 - acc: 0.0011
# Epoch 00005: loss improved from 0.42179 to 0.21267, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0557 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.21267 to 0.05569, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0306 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.05569 to 0.03056, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0260 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.03056 to 0.02601, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0249 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.02601 to 0.02491, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0242 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.02491 to 0.02425, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu2
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu3
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4218 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.42179, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.7199 - acc: 0.0000e+00
#
# Epoch 00002: loss did not improve from 0.42179
# Epoch 3/10
#  - 0s - loss: 1.7234 - acc: 0.0011
#
# Epoch 00003: loss did not improve from 0.42179
# Epoch 4/10
#  - 0s - loss: 0.6550 - acc: 0.0011
#
# Epoch 00004: loss did not improve from 0.42179
# Epoch 5/10
#  - 0s - loss: 0.2156 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.42179 to 0.21555, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0530 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.21555 to 0.05296, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0296 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.05296 to 0.02958, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0256 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.02958 to 0.02562, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0246 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.02562 to 0.02465, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0240 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.02465 to 0.02403, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu3
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu0
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu4
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0603 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06032, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0181 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06032 to 0.01814, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01814 to 0.01441, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01441 to 0.01413, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0140 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01413 to 0.01396, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01396 to 0.01381, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0137 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01381 to 0.01365, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01365 to 0.01350, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0134 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01350 to 0.01336, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu4
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu5
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0609 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06092, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0183 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06092 to 0.01828, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01828 to 0.01441, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01441 to 0.01411, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0139 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01411 to 0.01395, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01395 to 0.01379, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0136 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01379 to 0.01364, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01364 to 0.01349, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0133 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01349 to 0.01335, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu5
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu6
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0609 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06092, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0183 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06092 to 0.01828, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01828 to 0.01441, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01441 to 0.01411, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0139 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01411 to 0.01395, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01395 to 0.01379, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0136 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01379 to 0.01364, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01364 to 0.01349, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0133 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01349 to 0.01335, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu6
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu7
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5320 - acc: 0.0011
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0605 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06047, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0179 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06047 to 0.01792, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01792 to 0.01441, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01441 to 0.01414, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0140 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01414 to 0.01398, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01398 to 0.01382, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0137 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01382 to 0.01367, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01367 to 0.01352, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0134 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01352 to 0.01337, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu7
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu2
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu8
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0609 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06092, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0182 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06092 to 0.01820, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01820 to 0.01440, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01440 to 0.01411, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0139 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01411 to 0.01395, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01395 to 0.01379, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0136 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01379 to 0.01364, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01364 to 0.01349, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0133 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01349 to 0.01335, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu8
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu9
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0609 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06092, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0182 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06092 to 0.01820, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01820 to 0.01440, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01440 to 0.01411, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0139 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01411 to 0.01395, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01395 to 0.01379, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0136 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01379 to 0.01364, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01364 to 0.01349, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0133 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01349 to 0.01335, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu9
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu10
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0603 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06032, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0181 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06032 to 0.01814, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01814 to 0.01441, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01441 to 0.01413, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0140 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01413 to 0.01396, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01396 to 0.01381, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0137 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01381 to 0.01365, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01365 to 0.01351, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0134 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01351 to 0.01336, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu10
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu11
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0609 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06092, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0183 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06092 to 0.01828, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01828 to 0.01441, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01441 to 0.01411, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0139 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01411 to 0.01395, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01395 to 0.01379, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0136 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01379 to 0.01364, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01364 to 0.01349, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0133 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01349 to 0.01335, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu11
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu1
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu12
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0609 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06092, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0183 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06092 to 0.01828, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01828 to 0.01441, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01441 to 0.01411, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0139 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01411 to 0.01395, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01395 to 0.01379, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0136 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01379 to 0.01364, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01364 to 0.01349, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0133 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01349 to 0.01335, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu12
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu13
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0609 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06092, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0183 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06092 to 0.01828, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01828 to 0.01441, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01441 to 0.01411, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0139 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01411 to 0.01395, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01395 to 0.01379, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0136 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01379 to 0.01364, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01364 to 0.01349, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0133 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01349 to 0.01335, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu13
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu14
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5320 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.53196, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0603 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.53196 to 0.06032, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0181 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06032 to 0.01807, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0144 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.01807 to 0.01441, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0141 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.01441 to 0.01413, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0140 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.01413 to 0.01396, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0138 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.01396 to 0.01381, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0137 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.01381 to 0.01365, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0135 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.01365 to 0.01351, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0134 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.01351 to 0.01336, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu14
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu15
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5320 - acc: 0.0011
#
# ...
# convergeIndividualModel :
# Epoch 1/10
#  - 4s - loss: 0.2494 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.24944, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0614 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.24944 to 0.06144, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0524 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06144 to 0.05240, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0457 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.05240 to 0.04569, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0404 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.04569 to 0.04037, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0361 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.04037 to 0.03607, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0326 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.03607 to 0.03256, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0297 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.03256 to 0.02966, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0272 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.02966 to 0.02724, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0252 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.02724 to 0.02519, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu24
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu25
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 49], [1, 35], [2, 36], [0, 13]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 4s - loss: 0.2494 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.24944, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0614 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.24944 to 0.06144, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0524 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06144 to 0.05240, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0457 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.05240 to 0.04569, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0404 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.04569 to 0.04037, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0361 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.04037 to 0.03607, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0326 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.03607 to 0.03256, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0297 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.03256 to 0.02966, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0272 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.02966 to 0.02723, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0252 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.02723 to 0.02518, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu25
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu26
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 49], [1, 35], [2, 36], [0, 13]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 4s - loss: 0.2494 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.24944, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0614 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.24944 to 0.06144, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0524 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06144 to 0.05240, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0457 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.05240 to 0.04568, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0404 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.04568 to 0.04035, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0361 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.04035 to 0.03607, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0326 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.03607 to 0.03256, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0297 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.03256 to 0.02966, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0272 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.02966 to 0.02724, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0252 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.02724 to 0.02518, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu26
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu27
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 49], [1, 35], [2, 36], [0, 13]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 4s - loss: 0.2494 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.24944, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0614 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.24944 to 0.06144, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0524 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06144 to 0.05240, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0457 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.05240 to 0.04568, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0404 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.04568 to 0.04035, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0361 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.04035 to 0.03607, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0326 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.03607 to 0.03256, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0297 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.03256 to 0.02966, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0272 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.02966 to 0.02724, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0252 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.02724 to 0.02519, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu27
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time3/individu15
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu28
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 49], [1, 35], [2, 36], [0, 13]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 4s - loss: 0.2494 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.24944, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0610 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.24944 to 0.06104, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0520 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06104 to 0.05197, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0453 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.05197 to 0.04534, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0401 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.04534 to 0.04007, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0358 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.04007 to 0.03583, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0324 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.03583 to 0.03236, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0295 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.03236 to 0.02949, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0271 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.02949 to 0.02709, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0251 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.02709 to 0.02506, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu28
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu29
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 49], [1, 35], [2, 36], [0, 13]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 4s - loss: 0.2494 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.24944, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0610 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.24944 to 0.06104, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0520 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06104 to 0.05199, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0453 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.05199 to 0.04535, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0401 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.04535 to 0.04008, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0358 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.04008 to 0.03583, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0324 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.03583 to 0.03236, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0295 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.03236 to 0.02949, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0271 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.02949 to 0.02709, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0251 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.02709 to 0.02506, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu29
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu30
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 49], [1, 35], [2, 36], [0, 13]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 4s - loss: 0.2494 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.24944, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0610 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.24944 to 0.06104, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0520 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06104 to 0.05197, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0453 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.05197 to 0.04535, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0401 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.04535 to 0.04009, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0359 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.04009 to 0.03585, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0324 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.03585 to 0.03238, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0295 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.03238 to 0.02951, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0271 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.02951 to 0.02711, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0251 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.02711 to 0.02508, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu30
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu31
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 49], [1, 35], [2, 36], [0, 13]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 4s - loss: 0.2494 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.24944, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0610 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.24944 to 0.06104, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0520 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06104 to 0.05199, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0453 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.05199 to 0.04535, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0401 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.04535 to 0.04008, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0358 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.04008 to 0.03584, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0324 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.03584 to 0.03237, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0295 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.03237 to 0.02950, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0271 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.02950 to 0.02710, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0251 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.02710 to 0.02507, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu31
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time3/individu23
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu32
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 49], [1, 35], [2, 36], [0, 13]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 4s - loss: 0.2494 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.24944, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0610 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.24944 to 0.06104, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0520 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06104 to 0.05199, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0454 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.05199 to 0.04536, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0401 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.04536 to 0.04010, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0358 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.04010 to 0.03585, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0324 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.03585 to 0.03238, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0295 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.03238 to 0.02951, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0271 - acc: 0.0022
# Epoch 00009: loss improved from 0.02951 to 0.02711, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0251 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.02711 to 0.02508, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu32
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time4/individu33
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 49], [1, 35], [2, 36], [0, 13]]
# deltaNbNeuronList= [13, 5, 2, 1]
