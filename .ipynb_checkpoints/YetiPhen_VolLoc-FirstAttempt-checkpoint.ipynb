# %%
from sys import platform
import sys, os
# identification de la base de prix utilisée : directory principal
# sur ubuntu

path=''
if platform == 'linux' :
    path ='/workspace/NeuralPricing/A_GeneralizedSABR/CallOption'
# sur. mac osx
if platform == 'darwin' :
    path ='/Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc'
import keras,tensorflow,pkg_resources
dataDirectory='Data'
dataLearningFile = "1dim_VolLoc-Example-new.CSV"
dataNotationFile = "1dim_VolLoc-Example-new.CSV"
#datafile='Data/Baby_Learningbase1.CSV'
os.chdir(path)
# le package identifie la methode de calibration : sous-directory
# Out:
# /Users/olivier/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from __future__ import print_function
import tensorflow as tf
from math import sqrt, exp, log, erf,floor
import numpy 
import pandas
from decimal import *
import keras
from keras.layers import Dense
from keras.layers import Dropout
from keras import regularizers
from keras import callbacks
from keras.layers import Activation
from keras.layers import Lambda
from keras.models import Sequential
from keras.models import model_from_json
import keras.layers
import matplotlib
import matplotlib.pyplot as pyplot
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import mpl_toolkits
from mpl_toolkits.mplot3d import axes3d
from mpl_toolkits.mplot3d.axes3d import Axes3D
from sklearn import preprocessing
from sklearn import model_selection
import joblib
import seaborn as sns
import scipy
from IPython.display import display
import time
# %matplotlib inline
from IPython.display import display
from ipywidgets import interact, interactive, fixed, interact_manual,FloatProgress
import ipywidgets as widgets
import math

# %%
getcontext().prec = 8

from util_functions_YetiPhen_VolLoc import *

# %%
ListField1 ={"S1","mu1","bonus","YetiBarrier","YetiCoupon","PhoenixBarrier","PhoenixCoupon","PDIBarrier","PDIGearing","PDIStrike","PDIType",
             "maturity","nbDates"}

# %%
ListField2={"vol-date0-strike0","vol-date0-strike1","vol-date0-strike2","vol-date0-strike3","vol-date0-strike4","vol-date0-strike5","vol-date0-strike6",
           "vol-date0-strike7","vol-date0-strike8","vol-date0-strike9","vol-date0-strike10","vol-date0-strike11","vol-date0-strike12","vol-date0-strike13",
           "vol-date0-strike14","vol-date1-strike0","vol-date1-strike1","vol-date1-strike2","vol-date1-strike3","vol-date1-strike4","vol-date1-strike5",
           "vol-date1-strike6","vol-date1-strike7","vol-date1-strike8","vol-date1-strike9","vol-date1-strike10","vol-date1-strike11","vol-date1-strike12",
           "vol-date1-strike13","vol-date1-strike14","vol-date2-strike0","vol-date2-strike1","vol-date2-strike2","vol-date2-strike3","vol-date2-strike4",
           "vol-date2-strike5","vol-date2-strike6","vol-date2-strike7","vol-date2-strike8","vol-date2-strike9","vol-date2-strike10","vol-date2-strike11",
           "vol-date2-strike12","vol-date2-strike13","vol-date2-strike14","vol-date3-strike0","vol-date3-strike1","vol-date3-strike2","vol-date3-strike3",
           "vol-date3-strike4","vol-date3-strike5","vol-date3-strike6","vol-date3-strike7","vol-date3-strike8","vol-date3-strike9","vol-date3-strike10",
           "vol-date3-strike11","vol-date3-strike12","vol-date3-strike13","vol-date3-strike14","vol-date4-strike0","vol-date4-strike1","vol-date4-strike2",
           "vol-date4-strike3","vol-date4-strike4","vol-date4-strike5","vol-date4-strike6","vol-date4-strike7","vol-date4-strike8","vol-date4-strike9",
           "vol-date4-strike10","vol-date4-strike11","vol-date4-strike12","vol-date4-strike13","vol-date4-strike14","vol-date5-strike0","vol-date5-strike1",
           "vol-date5-strike2","vol-date5-strike3","vol-date5-strike4","vol-date5-strike5","vol-date5-strike6","vol-date5-strike7","vol-date5-strike8",
           "vol-date5-strike9","vol-date5-strike10","vol-date5-strike11","vol-date5-strike12","vol-date5-strike13","vol-date5-strike14","vol-date6-strike0",
           "vol-date6-strike1","vol-date6-strike2","vol-date6-strike3","vol-date6-strike4","vol-date6-strike5","vol-date6-strike6","vol-date6-strike7",
           "vol-date6-strike8","vol-date6-strike9","vol-date6-strike10","vol-date6-strike11","vol-date6-strike12","vol-date6-strike13","vol-date6-strike14",
           "vol-date7-strike0","vol-date7-strike1","vol-date7-strike2","vol-date7-strike3","vol-date7-strike4","vol-date7-strike5","vol-date7-strike6",
           "vol-date7-strike7","vol-date7-strike8","vol-date7-strike9","vol-date7-strike10","vol-date7-strike11","vol-date7-strike12","vol-date7-strike13",
           "vol-date7-strike14","vol-date8-strike0","vol-date8-strike1","vol-date8-strike2","vol-date8-strike3","vol-date8-strike4","vol-date8-strike5",
           "vol-date8-strike6","vol-date8-strike7","vol-date8-strike8","vol-date8-strike9","vol-date8-strike10","vol-date8-strike11","vol-date8-strike12",
           "vol-date8-strike13","vol-date8-strike14","vol-date9-strike0","vol-date9-strike1","vol-date9-strike2","vol-date9-strike3","vol-date9-strike4",
           "vol-date9-strike5","vol-date9-strike6","vol-date9-strike7","vol-date9-strike8","vol-date9-strike9","vol-date9-strike10","vol-date9-strike11",
           "vol-date9-strike12","vol-date9-strike13","vol-date9-strike14","vol-date10-strike0","vol-date10-strike1","vol-date10-strike2","vol-date10-strike3",
           "vol-date10-strike4","vol-date10-strike5","vol-date10-strike6","vol-date10-strike7","vol-date10-strike8","vol-date10-strike9","vol-date10-strike10",
           "vol-date10-strike11","vol-date10-strike12","vol-date10-strike13","vol-date10-strike14","vol-date11-strike0","vol-date11-strike1","vol-date11-strike2",
           "vol-date11-strike3","vol-date11-strike4","vol-date11-strike5","vol-date11-strike6","vol-date11-strike7",
           "vol-date11-strike8","vol-date11-strike9","vol-date11-strike10","vol-date11-strike11","vol-date11-strike12","vol-date11-strike13","vol-date11-strike14"}

# %%
params=metaparameters()

params.INPUT_DIM  = 193
params.INPUT_OPTION = 193
params.INPUT_VOL =13
params.NB_NEURON_PRINCIPAL =8
params.ACTIVATION_PRINCIPALE = 'tanh'
params.ACTIVATION_PRINCIPALE_FINALE = 'linear'
params.INITIAL_LEARNING_NB_EPOCH=1000
params.LEARNINGBASE_ORIGIN="New_Test"
params.LEARNINGBASE_BUT="New_Simu_Test"
params.GENETIC_LEARNING_NB_EPOCH = 10
params.BATCH_SIZE_PRINCIPAL = 32768
params.OPTIMIZER='adamax'
params.OPTIMIZER_GENETIC='SGD'
params.NBLAYERS = 11
params.NB_LOOPS = 5
params.PATH = path
params.VERBOSE_FLAG=2
params.EPSILON_GREEDINESS = 0.25
params.EPSILON_GREEDINESS_DECREASING_FACTOR = 0.99
params.INITIAL_NETWORK_STRUCTURE = [[0,10],[1,20],[2,30],[0,10]]
params.NOTATION_FILE = dataDirectory+'/'+dataNotationFile
params.LISTFIELD1=ListField1
params.LISTFIELD2=ListField2

# %%
startTime = time.time()
dataframe = pandas.read_csv(dataDirectory+"/"+dataLearningFile)
endTime = time.time()
print('temps de lecture du ficher',endTime - startTime)
X = dataframe[ListField1.union(ListField2)];
Y_Vol = dataframe['price'];
datasize=X.size
X_scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
X_scaled = (X_scaler.fit_transform(X))
params.X_scaler = X_scaler
params.X_scaled = X_scaled
params.X = X
Y_scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
Y_scaled = (Y_scaler.fit_transform(np.array(Y_Vol).reshape(-1, 1))).reshape(1, -1)[0]
params.Y_scaler = Y_scaler
params.Y_scaled = Y_scaled
params.Y_Vol = Y_Vol

startTime = time.time()
dataframe = pandas.read_csv(dataDirectory+"/"+dataNotationFile)
endTime = time.time()
print('temps de lecture du ficher',endTime - startTime)
X = dataframe[ListField1.union(ListField2)];
Y_Vol = dataframe['price'];
datasize=X.size
X_scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
X_scaled = (X_scaler.fit_transform(X))
params.X_Notation_scaler = X_scaler
params.X_Notation_scaled = X_scaled
params.X_Notation = X
Y_scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
Y_scaled = (Y_scaler.fit_transform(np.array(Y_Vol).reshape(-1, 1))).reshape(1, -1)[0]
params.Y_Notation_scaler = Y_scaler
params.Y_Notation_scaled = Y_scaled
params.Y_Notation_Vol = Y_Vol
# Out:
# temps de lecture du ficher 0.04388904571533203
# temps de lecture du ficher 0.03676199913024902

# %%
#Y_ordre1_Vol,model_Initial,y_scaler_Vol,y_scaled_Vol=InitialCalibration2(params.Y_Vol,"Vol",params)

# %%
nbloop =10
pkgNameOriginal = params.LEARNINGBASE_ORIGIN
pkgNameBut = params.LEARNINGBASE_BUT
Y_ordre1,model2,y_scaler,y_scaled,resultats=ReinforceOptimality2(pkgNameOriginal,pkgNameBut,nbloop,"Vol",params)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0914 12:30:12.999386 4746241472 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0914 12:30:13.021683 4746241472 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0914 12:30:13.119016 4746241472 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0914 12:30:13.119621 4746241472 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0914 12:30:13.120174 4746241472 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0914 12:30:13.336509 4746241472 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Note = 6.931411625019766
# noteinitiale= 6.931411625019766
# i= 0
# NbLayers= 4
# New model synthesized
# starting fit
# Epoch 1/10
#  - 0s - loss: 0.0046 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.00459, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.00459 to 0.00425, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.00425 to 0.00418, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.00418 to 0.00415, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.00415 to 0.00414, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.00414 to 0.00413, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.00413 to 0.00412, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.00412 to 0.00412, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.00412 to 0.00411, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.00411 to 0.00410, saving model to BestWeights.hdf5
# temps de calibration  0.7248692512512207
# starting to save
# Saved model to disk as Vol
# number of additional learning : 1
# Note = 6.148674372401928
# notefinale= 6.148674372401928
# Note = 6.931411625019766
# noteinitiale= 6.931411625019766
# i= 0
# NbLayers= 4
# New model synthesized
# starting fit
# Epoch 1/10
#  - 0s - loss: 0.0046 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.00459, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.00459 to 0.00425, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.00425 to 0.00418, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.00418 to 0.00415, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.00415 to 0.00414, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.00414 to 0.00413, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.00413 to 0.00412, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.00412 to 0.00412, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.00412 to 0.00411, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.00411 to 0.00410, saving model to BestWeights.hdf5
# temps de calibration  0.8088212013244629
# starting to save
# Saved model to disk as Vol
# number of additional learning : 2
# Note = 6.14863484116965
# notefinale= 6.14863484116965
# Note = 6.931411625019766
# noteinitiale= 6.931411625019766
# i= 1
# NbLayers= 4
# New model synthesized
# starting fit
# Epoch 1/10
#  - 0s - loss: 0.0046 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.00459, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.00459 to 0.00425, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.00425 to 0.00418, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.00418 to 0.00415, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.00415 to 0.00414, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.00414 to 0.00413, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.00413 to 0.00412, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.00412 to 0.00412, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.00412 to 0.00411, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.00411 to 0.00410, saving model to BestWeights.hdf5
# temps de calibration  0.9698660373687744
# starting to save
# Saved model to disk as Vol
# number of additional learning : 3
# Note = 6.148631154216234
# notefinale= 6.148631154216234
# Note = 6.931411625019766
# noteinitiale= 6.931411625019766
# i= 0
# NbLayers= 4
# New model synthesized
# starting fit
# Epoch 1/10
#  - 0s - loss: 0.0046 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.00459, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.00459 to 0.00425, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.00425 to 0.00418, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.00418 to 0.00415, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.00415 to 0.00414, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.00414 to 0.00413, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.00413 to 0.00412, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.00412 to 0.00412, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.00412 to 0.00411, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.00411 to 0.00410, saving model to BestWeights.hdf5
# temps de calibration  0.8793132305145264
# starting to save
# Saved model to disk as Vol
# number of additional learning : 4
# Note = 6.148637469649815
# notefinale= 6.148637469649815
# Note = 6.931411625019766
# noteinitiale= 6.931411625019766
# i= 3
# NbLayers= 4
# New model synthesized
# starting fit
# Epoch 1/10
#  - 0s - loss: 0.0046 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.00459, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.00459 to 0.00425, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.00425 to 0.00418, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.00418 to 0.00415, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.00415 to 0.00414, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.00414 to 0.00413, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.00413 to 0.00412, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.00412 to 0.00412, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.00412 to 0.00411, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.00411 to 0.00410, saving model to BestWeights.hdf5
# temps de calibration  0.996668815612793
# starting to save
# Saved model to disk as Vol
# number of additional learning : 5
# Note = 6.148632588245167
# notefinale= 6.148632588245167
# Note = 6.931411625019766
# noteinitiale= 6.931411625019766
# i= 2
# NbLayers= 4
# New model synthesized
# starting fit
# Epoch 1/10
#  - 0s - loss: 0.0046 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.00459, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.00459 to 0.00425, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.00425 to 0.00418, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.00418 to 0.00415, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.00415 to 0.00414, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.00414 to 0.00413, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.00413 to 0.00412, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.00412 to 0.00412, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.00412 to 0.00411, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.00411 to 0.00410, saving model to BestWeights.hdf5
# temps de calibration  1.2084400653839111
# starting to save
# Saved model to disk as Vol
# number of additional learning : 6
# Note = 6.148628579460286
# notefinale= 6.148628579460286
# Note = 6.931411625019766
# noteinitiale= 6.931411625019766
# i= 5
# NbLayers= 4
# New model synthesized
# starting fit
# Epoch 1/10
#  - 0s - loss: 0.0046 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.00459, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.00459 to 0.00425, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.00425 to 0.00418, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.00418 to 0.00415, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.00415 to 0.00414, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.00414 to 0.00413, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.00413 to 0.00412, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.00412 to 0.00412, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.00412 to 0.00411, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.00411 to 0.00410, saving model to BestWeights.hdf5
# temps de calibration  1.394773244857788
# starting to save
# Saved model to disk as Vol
# number of additional learning : 7
# Note = 6.148616711137056
# notefinale= 6.148616711137056
# Note = 6.931411625019766
# noteinitiale= 6.931411625019766
# i= 2
# NbLayers= 4
# New model synthesized
# starting fit
# Epoch 1/10
#  - 0s - loss: 0.0046 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.00459, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.00459 to 0.00425, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.00425 to 0.00418, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.00418 to 0.00415, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.00415 to 0.00414, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.00414 to 0.00413, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.00413 to 0.00412, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.00412 to 0.00412, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.00412 to 0.00411, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.00411 to 0.00410, saving model to BestWeights.hdf5
# temps de calibration  1.3840100765228271
# starting to save
# Saved model to disk as Vol
# number of additional learning : 8
# Note = 6.148618484586408
# notefinale= 6.148618484586408
# Note = 6.931411625019766
# noteinitiale= 6.931411625019766
# i= 6
# NbLayers= 4
# New model synthesized
# starting fit
# Epoch 1/10
#  - 0s - loss: 0.0046 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.00459, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.00459 to 0.00425, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.00425 to 0.00418, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.00418 to 0.00415, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.00415 to 0.00414, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.00414 to 0.00413, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.00413 to 0.00412, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.00412 to 0.00412, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.00412 to 0.00411, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.00411 to 0.00410, saving model to BestWeights.hdf5
# temps de calibration  1.527683973312378
# starting to save
# Saved model to disk as Vol
# number of additional learning : 9
# Note = 6.148619983229136
# notefinale= 6.148619983229136
# Note = 6.931411625019766
# noteinitiale= 6.931411625019766
# i= 2
# NbLayers= 4
# New model synthesized
# starting fit
# Epoch 1/10
#  - 0s - loss: 0.0046 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.00459, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.00459 to 0.00425, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.00425 to 0.00418, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0042 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.00418 to 0.00415, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.00415 to 0.00414, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.00414 to 0.00413, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.00413 to 0.00412, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.00412 to 0.00412, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.00412 to 0.00411, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0041 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.00411 to 0.00410, saving model to BestWeights.hdf5
# temps de calibration  1.688751220703125
# starting to save
# Saved model to disk as Vol
# number of additional learning : 10
# Note = 6.148619989261758
# notefinale= 6.148619989261758

# %% [markdown]
# # Test des Modules d'Injection

# %%
speclist =[[0,10],[1,20],[0,30],[0,10]]
mm =buidModel(speclist,params)
print(mm.summary())
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0917 14:31:10.059463 4552287680 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0917 14:31:10.078676 4552287680 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0917 14:31:10.084741 4552287680 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 193)          0
# __________________________________________________________________________________________________
# Layer0 (Dense)                  (None, 10)           1940        input_1[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_type11 (Dense)      (None, 20)           220         Layer0[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_Multiplier1 (Dense) (None, 10)           200         ResnetLayer_type11[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 10)           0           ResnetLayer_Multiplier1[0][0]
#                                                                  Layer0[0][0]
# __________________________________________________________________________________________________
# Layer2 (Dense)                  (None, 30)           330         add_1[0][0]
# __________________________________________________________________________________________________
# Layer3 (Dense)                  (None, 10)           310         Layer2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            11          Layer3[0][0]
# ==================================================================================================
# Total params: 3,011
# Trainable params: 3,011
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
speclist =[[0,10],[2,20],[0,30],[0,10]]
mm =buidModel(speclist,params)
print(mm.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 193)          0
# __________________________________________________________________________________________________
# Layer0 (Dense)                  (None, 10)           1940        input_2[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_type21 (Dense)      (None, 20)           220         Layer0[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_Multiplier1 (Dense) (None, 20)           200         Layer0[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 20)           0           ResnetLayer_type21[0][0]
#                                                                  ResnetLayer_Multiplier1[0][0]
# __________________________________________________________________________________________________
# Layer2 (Dense)                  (None, 30)           630         add_2[0][0]
# __________________________________________________________________________________________________
# Layer3 (Dense)                  (None, 10)           310         Layer2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            11          Layer3[0][0]
# ==================================================================================================
# Total params: 3,311
# Trainable params: 3,311
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
mm =buidModel(specList,params)
deltaNbNeuronList= [13, 5, 2, 1]
mm1 =injectionModel(mm,specList,deltaNbNeuronList,params) 
print(mm1.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           (None, 193)          0
# __________________________________________________________________________________________________
# Layer0 (Dense)                  (None, 23)           4462        input_10[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_type11 (Dense)      (None, 25)           600         Layer0[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_Multiplier1 (Dense) (None, 23)           575         ResnetLayer_type11[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 23)           0           ResnetLayer_Multiplier1[0][0]
#                                                                  Layer0[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_type22 (Dense)      (None, 32)           768         add_18[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_Multiplier2 (Dense) (None, 32)           736         add_18[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32)           0           ResnetLayer_type22[0][0]
#                                                                  ResnetLayer_Multiplier2[0][0]
# __________________________________________________________________________________________________
# Layer3 (Dense)                  (None, 11)           363         add_19[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            12          Layer3[0][0]
# ==================================================================================================
# Total params: 7,516
# Trainable params: 7,516
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
cnfigName="Vol"
pkgPath="New_Test"
loaded_model,X_scaler_loaded,y_scaler_loaded,y_scaled_loaded,Y_ordre1_loaded,loaded_speclist = reloadModel(cnfigName,pkgPath)
# Out:
# W0917 17:02:46.584270 4541294016 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0917 17:02:46.584897 4541294016 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0917 17:02:46.585605 4541294016 deprecation_wrapper.py:119] From /Users/olivier/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.

# %%
deltaspecList=[0,10,0,0]
mm1 =injectionModel(loaded_model,loaded_speclist,deltaspecList,params) 
##print(mm1.summary())
Compute_Note(loaded_model,params)
Compute_Note(mm1,params);
# Out:
# Note = 72.16377802483674
# Note = 72.16377826776501

# %%
ResnetRank=2
ResnetWeight=35
ResnetType=1
mm2=injectionModelWithInsertion(loaded_model,loaded_speclist,ResnetRank,ResnetWeight,ResnetType,params)
##print(mm2.summary())
Compute_Note(loaded_model,params)
Compute_Note(mm2,params);
# Out:
# Note = 72.16377802483674
# Note = 72.16377802483674

# %%
def buildParamList(modelspecList,params) : 
    model = buidModel(modelspecList,params)   
    weights1=model.get_weights()
    return list(map(lambda k: k.shape ,weights1))

# %%
ResnetRank=2
ResnetWeight=35
ResnetType=1
mm2=injectionModelWithInsertion(loaded_model,loaded_speclist,ResnetRank,ResnetWeight,ResnetType,params)
print(mm2.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 193)          0
# __________________________________________________________________________________________________
# Layer0 (Dense)                  (None, 10)           1940        input_6[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_type11 (Dense)      (None, 20)           220         Layer0[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_Multiplier1 (Dense) (None, 10)           200         ResnetLayer_type11[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 10)           0           ResnetLayer_Multiplier1[0][0]
#                                                                  Layer0[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_type12 (Dense)      (None, 35)           385         add_9[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_Multiplier2 (Dense) (None, 10)           350         ResnetLayer_type12[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 10)           0           ResnetLayer_Multiplier2[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_type23 (Dense)      (None, 30)           330         add_10[0][0]
# __________________________________________________________________________________________________
# ResnetLayer_Multiplier3 (Dense) (None, 30)           300         add_10[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 30)           0           ResnetLayer_type23[0][0]
#                                                                  ResnetLayer_Multiplier3[0][0]
# __________________________________________________________________________________________________
# Layer4 (Dense)                  (None, 10)           310         add_11[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            11          Layer4[0][0]
# ==================================================================================================
# Total params: 4,046
# Trainable params: 4,046
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
def CountIndividuals(a)    :
    ii=0
    for f in os.listdir(a):
        ii=ii+1
    return ii

# %%
def convergeIndividualModel(model,params):
    print('convergeIndividualModel :')
    model.compile(loss='mse', optimizer='SGD', metrics=["accuracy"])
    X_train, X_test, y_train, y_test = model_selection.train_test_split( \
            params.X_scaled, params.Y_scaled, test_size=0.10, random_state=3)
    checkpointer = keras.callbacks.ModelCheckpoint(filepath = "BestWeights.hdf5",verbose=1,\
                                                   save_best_only=True , monitor = 'loss')
    numpy.random.seed(3)
    model.fit(X_train, y_train, epochs=params.GENETIC_LEARNING_NB_EPOCH, batch_size=params.BATCH_SIZE_PRINCIPAL,\
              verbose=params.VERBOSE_FLAG, shuffle = True, callbacks=[checkpointer])

# %%
def ComputeBestNoteIndexlist(ListOfnote,populationctrlFunc,iTimeStep):
    lenlist = len(ListOfnote)
    sortedlist = np.argsort(ListOfnote)
    lim = populationctrlFunc(iTimeStep)
    lim = min(lenlist,lim)
    print('lim=',lim)
    ListOfWorst=sortedlist[lim:] 
    ListOfBest=sortedlist[:lim]
    return ListOfWorst,ListOfBest

# %%
def pathCreatechild(TimePath,individualpath,child):
    pathCreated = TimePath + '/individu' +  str(child)
    if not(os.path.isdir(pathCreated)):
                os.makedirs(pathCreated,0o777 )
    print('pathCreatechild=',pathCreated)
    return pathCreated

# %%
def killIndividual(individualPath):
    print("killing :",individualPath)
    shutil.rmtree(individualPath)

# %%
def saveIndividualModel(model,X_scaler,y_scaler,y_scaled,Y_ordre1,specList,path,cnfigName):
    model.save_weights(path + '/' + cnfigName +'.hdf5')
    # save model to JSON
    model_json = model.to_json()
    with open(path + '/' + cnfigName +'.json', 'w') as json_file:
        json_file.write(model_json)
    # Save scaler Xand Y
    filename = path + '/' + cnfigName +'scalerX.pkl'
    _= joblib.dump(X_scaler , filename , compress = 9)
    filename = path + '/' + cnfigName +'scalerY.pkl'
    _= joblib.dump(y_scaler , filename , compress = 9)
    filename = path + '/' + cnfigName +'scaledY.pkl'
    _= joblib.dump(y_scaled , filename , compress = 9)
    filename = path + '/' + cnfigName +'Y_ordre1.res'
    _= joblib.dump(Y_ordre1 , filename , compress = 9)
    filename = path + '/' + cnfigName +'current_structure.str'
    _= joblib.dump(specList , filename , compress = 9)
    print('saveIndividualModel model2 at :',path)

# %%
def loadInvidualModel(IndividuPath,cnfigName):
    json_file = open(IndividuPath+ "/"+ cnfigName  +'.json', 'r')
    file = IndividuPath+ '/' + cnfigName  +'.json'
    
    loaded_model_json = json_file.read()
    json_file.close()  
    loaded_model = model_from_json(loaded_model_json)           
    filename2 = IndividuPath+ '/' + cnfigName  +'current_structure.str'
    specList = joblib.load(filename2 )
    filename2 = IndividuPath+ '/' + cnfigName  +'scalerY.pkl'
    y_scaler = joblib.load(filename2)
    filename2 = IndividuPath+ '/' + cnfigName  +'scaledY.pkl'
    y_scaled = joblib.load(filename2)
    print('loadInvidualModel :IndividuPath=',IndividuPath)
    return loaded_model, specList,y_scaler,y_scaled

# %%
def BulleListPar(i,NbLayers):
    return [floor(exp(2.5-2*abs(x-i)/(0.5*NbLayers)))+1 for x in range(NbLayers)]

# %%
BulleListPar(0,11)
# Out:
# [13, 9, 6, 5, 3, 2, 2, 1, 1, 1, 1]

# %%
def mutateIndividualModel(model,specList,params):
    NbLayers = len(specList)
    deltaNbNeuronList = BulleListPar(0,NbLayers)
    print('mutateIndividualModel : adding neurons',deltaNbNeuronList)
    print('specList=',specList)
    print('deltaNbNeuronList=',deltaNbNeuronList)
    model2 =injectionModel(model,specList,deltaNbNeuronList,params) 
    specList2 = [[specList[i][0],specList[i][1]+  deltaNbNeuronList[i] ] for i in range(NbLayers)]
    
    return model2,specList2

# %%
def copyModelFromInitial(originalModelPath,IndividuPath):
    shutil.copyfile(originalModelPath+'current_structure.str',IndividuPath+'current_structure.str')
    shutil.copyfile(originalModelPath+'scalerY.pkl',IndividuPath+'scalerY.pkl')
    shutil.copyfile(originalModelPath+'scaledY.pkl',IndividuPath+'scaledY.pkl')

# %%
def createResidues(X,X_scaler,model,y_scaler,Ycall,generate_errors):
    Y_size = X.shape[0]
    print("creating the residus for the boosting")
    Y_ordre1=numpy.zeros(Ycall.size); 
    if (generate_errors):        
        for i in range(Y_size):
            normalizedData=X_scaler.transform(X[i].reshape(1, -1))
            normalizedPrediction=model.predict(normalizedData)
            outputData=y_scaler.inverse_transform(normalizedPrediction)
            Y_ordre1[i]=outputData[0,0]-Ycall[i]
        return Y_ordre1
    else:
        return Y_ordre1

# %%
def ComputeIndividualNote(individualpath,cnfigName,params):
    file = individualpath+'/' +cnfigName +'.json'
    os.chdir(individualpath)
    json_file = open(file, 'r')
    loaded_model_json = json_file.read()
    json_file.close()              
    model = model_from_json(loaded_model_json)              ### chargment du model initial (1)
    file = individualpath +'/'+cnfigName +'.hdf5'
    model.load_weights(file)  ### chargment du model initial (2)
    note = Compute_Note(model,params)
    return note

# %%
def Idealpopulation(nstep):
    if (nstep<4): 
        return 3*nstep+2
    else:
        return 20

# %%
def ReinforceOptimalityWithGenetic(pkgNameOriginal,pkgNameBut,InitialNbIndividual,populationctrlFunc,nbChildAllowed,\
                         nbloop,Ycall,cnfigName,params,save=True,generate_errors = False):
    originalModelPath=params.PATH + "/" + pkgNameOriginal   
    filename = originalModelPath + '/' + cnfigName +'scaledY.pkl'
    y_scaled = joblib.load(filename)
    filename = originalModelPath + '/' + cnfigName +'scalerY.pkl'
    y_scaler = joblib.load(filename)
    X_train, X_test, y_train, y_test = model_selection.train_test_split( \
                params.X_scaled, y_scaled, test_size=0.10, random_state=3)
    SimuPath = params.PATH + "/" + pkgNameBut 
    if not(os.path.isdir(SimuPath)):
        os.makedirs(SimuPath,0o777 )
    SimuPath = SimuPath + '/loop'
    if (os.path.isdir(SimuPath)):
        shutil.rmtree(SimuPath)
    os.makedirs(SimuPath,0o777 ) 
    precedingIndividualPathList =[]
    for iTimeStep in range(nbloop):
        TimePath = SimuPath + "/" + "time"+str(iTimeStep) 
        if not(os.path.isdir(TimePath)):
                os.makedirs(TimePath,0o777 )
                print("created : ",TimePath)
        if (iTimeStep == 0) :
            for individual in range(InitialNbIndividual):
                IndividuPath= TimePath +  "/individu" + str(individual)
                if not(os.path.isdir(IndividuPath)):
                        os.makedirs(IndividuPath,0o777 )
                        print("created : ",IndividuPath)
                ## ....traitement
                model,specList,y_scaler,y_scaled = loadInvidualModel(originalModelPath,cnfigName)
                model2,specList2=mutateIndividualModel(model,specList,params)
                convergeIndividualModel(model2,params)
                Y_ordre1 = createResidues(params.X,X_scaler,model2,y_scaler,Ycall,generate_errors)
                saveIndividualModel(model2,X_scaler,y_scaler,y_scaled,Y_ordre1,specList,IndividuPath,cnfigName)   
                ## .. Fin du traitement
                precedingIndividualPathList.append(IndividuPath)                     
        else :
            invidualpathList = []
            individuNumero =0
            for individualpath in precedingIndividualPathList:                            
            ## ....traitement
                model,specList,y_scaler,y_scaled = loadInvidualModel(individualpath,cnfigName)
                for child in range(nbChildAllowed): 
                    childPath = pathCreatechild(TimePath,individualpath,individuNumero)
                    individuNumero +=1
                    model2,specList2=mutateIndividualModel(model,specList,params)
                    convergeIndividualModel(model2,params)
                    Y_ordre1 = createResidues(params.X,X_scaler,model2,y_scaler,Ycall,generate_errors)
                    saveIndividualModel(model2,X_scaler,y_scaler,y_scaled,Y_ordre1,specList2,childPath,cnfigName)
                    invidualpathList.append(childPath)
                precedingIndividualPathList = invidualpathList
            ## .. Fin du traitement
        ## .. Debut Selection Naturelle
        ListOnote =[]
        invidualpathList = precedingIndividualPathList
        for individualpath in invidualpathList :
            note = ComputeIndividualNote(individualpath,cnfigName,params)
            ListOnote.append(note)
        worstNoteIndexlist,bestNoteIndexlist = ComputeBestNoteIndexlist(ListOnote,populationctrlFunc,iTimeStep)
        print('ListOnote=',ListOnote)
        print('bestNoteIndexlist=',bestNoteIndexlist)
        print('worstNoteIndexlist=',worstNoteIndexlist)
        for index in worstNoteIndexlist : 
            killIndividual(invidualpathList[index])
        precedingIndividualPathList = [invidualpathList[index] for index in bestNoteIndexlist]

# %%
nbloop =5;NbIndividual =3; nbChildAllowed =4
pkgNameOriginal = params.LEARNINGBASE_ORIGIN
pkgNameBut = params.LEARNINGBASE_BUT
InitialNbIndividual =3;naturalSelectionPercentage =0.5
a=ReinforceOptimalityWithGenetic(pkgNameOriginal,pkgNameBut,InitialNbIndividual,Idealpopulation,nbChildAllowed,\
                       nbloop,Y_Vol,"Vol",params)
# Out:
# created :  /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0
# created :  /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu0
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Test
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 0.0851 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 0.08512, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0640 - acc: 0.0000e+00
#
# Epoch 00002: loss improved from 0.08512 to 0.06398, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0558 - acc: 0.0000e+00
#
# Epoch 00003: loss improved from 0.06398 to 0.05578, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0505 - acc: 0.0000e+00
#
# Epoch 00004: loss improved from 0.05578 to 0.05052, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0465 - acc: 0.0000e+00
#
# Epoch 00005: loss improved from 0.05052 to 0.04651, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0431 - acc: 0.0000e+00
#
# Epoch 00006: loss improved from 0.04651 to 0.04314, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0403 - acc: 0.0000e+00
#
# Epoch 00007: loss improved from 0.04314 to 0.04025, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0377 - acc: 0.0000e+00
#
# Epoch 00008: loss improved from 0.04025 to 0.03775, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0356 - acc: 0.0000e+00
#
# Epoch 00009: loss improved from 0.03775 to 0.03555, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0336 - acc: 0.0000e+00
#
# Epoch 00010: loss improved from 0.03555 to 0.03362, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu0
# created :  /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu1
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Test
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 0.9825 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 0.98247, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0469 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.98247 to 0.04687, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0256 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.04687 to 0.02557, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0202 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02557 to 0.02018, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0185 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.02018 to 0.01846, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01846 to 0.01763, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0170 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01763 to 0.01705, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01705 to 0.01656, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01656 to 0.01612, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0157 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01612 to 0.01573, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu1
# created :  /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu2
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Test
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 0.9825 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 0.98247, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0449 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.98247 to 0.04487, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0247 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.04487 to 0.02465, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0197 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02465 to 0.01971, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0182 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01971 to 0.01817, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0174 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01817 to 0.01740, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0168 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01740 to 0.01684, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01684 to 0.01637, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0159 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01637 to 0.01594, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0156 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01594 to 0.01555, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu2
# Note = 6.780278201362299
# Note = 6.135216803466587
# Note = 6.737467067540296
# lim= 2
# ListOnote= [6.780278201362299, 6.135216803466587, 6.737467067540296]
# bestNoteIndexlist= [1 2]
# worstNoteIndexlist= [0]
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu0
# created :  /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu1
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu0
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 1.3099 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 1.30985, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0685 - acc: 0.0022
#
# Epoch 00002: loss improved from 1.30985 to 0.06853, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0279 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06853 to 0.02792, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0256 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.02792 to 0.02555, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0246 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.02555 to 0.02458, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0237 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.02458 to 0.02372, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0229 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.02372 to 0.02293, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0222 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.02293 to 0.02221, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0215 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.02221 to 0.02154, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0209 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.02154 to 0.02093, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu0
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu1
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 1.3099 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 1.30985, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0645 - acc: 0.0022
#
# Epoch 00002: loss improved from 1.30985 to 0.06454, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0288 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06454 to 0.02877, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0267 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.02877 to 0.02673, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0257 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.02673 to 0.02566, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0247 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.02566 to 0.02470, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0238 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.02470 to 0.02382, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0230 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.02382 to 0.02302, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0223 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.02302 to 0.02228, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0216 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.02228 to 0.02161, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu1
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu2
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 1.3099 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 1.30985, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0645 - acc: 0.0022
#
# Epoch 00002: loss improved from 1.30985 to 0.06454, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0288 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06454 to 0.02877, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0267 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.02877 to 0.02673, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0257 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.02673 to 0.02566, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0247 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.02566 to 0.02470, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0238 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.02470 to 0.02382, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0230 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.02382 to 0.02302, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0223 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.02302 to 0.02228, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0216 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.02228 to 0.02161, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu2
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu3
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 1.3099 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 1.30985, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0685 - acc: 0.0022
#
# Epoch 00002: loss improved from 1.30985 to 0.06853, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0279 - acc: 0.0022
#
# Epoch 00003: loss improved from 0.06853 to 0.02792, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0256 - acc: 0.0022
#
# Epoch 00004: loss improved from 0.02792 to 0.02555, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0246 - acc: 0.0022
#
# Epoch 00005: loss improved from 0.02555 to 0.02458, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0237 - acc: 0.0022
#
# Epoch 00006: loss improved from 0.02458 to 0.02372, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0229 - acc: 0.0022
#
# Epoch 00007: loss improved from 0.02372 to 0.02293, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0222 - acc: 0.0022
#
# Epoch 00008: loss improved from 0.02293 to 0.02221, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0215 - acc: 0.0022
#
# Epoch 00009: loss improved from 0.02221 to 0.02154, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0209 - acc: 0.0022
#
# Epoch 00010: loss improved from 0.02154 to 0.02093, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu3
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time0/individu2
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu4
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0630 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06298, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0214 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06298 to 0.02140, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02140 to 0.01765, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01765 to 0.01724, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01724 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01636, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01636 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01582, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu4
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu5
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0628 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06280, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0213 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06280 to 0.02125, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02125 to 0.01763, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01763 to 0.01723, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01723 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01635, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
# Epoch 00009: loss improved from 0.01635 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01582, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu5
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu6
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0630 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06298, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0214 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06298 to 0.02140, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02140 to 0.01765, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01765 to 0.01724, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01724 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01636, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01636 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01582, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu6
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu7
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 10], [1, 20], [2, 30], [0, 10]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 0s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0630 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06298, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0214 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06298 to 0.02140, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02140 to 0.01765, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01765 to 0.01724, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01724 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01636, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01636 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01582, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu7
# Note = 8.660537493747015
# Note = 8.658519098074049
# Note = 8.658501337720013
# Note = 8.660973366908271
# Note = 61.02233036016111
# Note = 60.97363590664738
# Note = 61.02239652918419
# Note = 61.02234637918885
# lim= 5
# ListOnote= [8.660537493747015, 8.658519098074049, 8.658501337720013, 8.660973366908271, 61.02233036016111, 60.97363590664738, 61.02239652918419, 61.02234637918885]
# bestNoteIndexlist= [2 1 0 3 5]
# worstNoteIndexlist= [4 7 6]
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu4
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu7
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu6
# created :  /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu2
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu0
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5409 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 0.54093, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 1.2527 - acc: 0.0000e+00
#
# Epoch 00002: loss did not improve from 0.54093
# Epoch 3/10
#  - 0s - loss: 1.0727 - acc: 0.0011
#
# Epoch 00003: loss did not improve from 0.54093
# Epoch 4/10
#  - 0s - loss: 0.5181 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.54093 to 0.51809, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0699 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.51809 to 0.06995, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0471 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.06995 to 0.04705, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0424 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.04705 to 0.04239, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0388 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.04239 to 0.03880, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0358 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.03880 to 0.03579, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0333 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.03579 to 0.03326, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu0
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu1
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5409 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 0.54093, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 1.2527 - acc: 0.0000e+00
#
# Epoch 00002: loss did not improve from 0.54093
# Epoch 3/10
#  - 0s - loss: 1.0727 - acc: 0.0011
#
# Epoch 00003: loss did not improve from 0.54093
# Epoch 4/10
#  - 0s - loss: 0.5114 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.54093 to 0.51144, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0692 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.51144 to 0.06917, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0466 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.06917 to 0.04659, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0420 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.04659 to 0.04200, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0385 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.04200 to 0.03847, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0355 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.03847 to 0.03552, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0330 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.03552 to 0.03302, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu1
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu2
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5409 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 0.54093, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 1.2728 - acc: 0.0000e+00
#
# Epoch 00002: loss did not improve from 0.54093
# Epoch 3/10
#  - 0s - loss: 1.0548 - acc: 0.0011
#
# Epoch 00003: loss did not improve from 0.54093
# Epoch 4/10
#  - 0s - loss: 0.5095 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.54093 to 0.50947, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0691 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.50947 to 0.06910, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0468 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.06910 to 0.04679, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0421 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.04679 to 0.04213, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0385 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.04213 to 0.03854, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0355 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.03854 to 0.03554, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0330 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.03554 to 0.03302, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu2
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu3
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.5409 - acc: 0.0000e+00
#
# Epoch 00001: loss improved from inf to 0.54093, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 1.2527 - acc: 0.0000e+00
#
# Epoch 00002: loss did not improve from 0.54093
# Epoch 3/10
#  - 0s - loss: 1.0082 - acc: 0.0011
#
# Epoch 00003: loss did not improve from 0.54093
# Epoch 4/10
#  - 0s - loss: 0.4949 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.54093 to 0.49492, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0715 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.49492 to 0.07149, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0484 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.07149 to 0.04835, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0433 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.04835 to 0.04331, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0395 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.04331 to 0.03953, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0364 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.03953 to 0.03640, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0338 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.03640 to 0.03376, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu3
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu1
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu4
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0628 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06280, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0213 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06280 to 0.02132, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02132 to 0.01764, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01764 to 0.01723, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01723 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01635, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01635 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01581, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu4
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu5
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0628 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06280, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0213 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06280 to 0.02132, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02132 to 0.01764, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01764 to 0.01723, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01723 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01663, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01663 to 0.01635, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01635 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01581, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu5
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu6
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0630 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06298, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0214 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06298 to 0.02140, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02140 to 0.01765, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01765 to 0.01724, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01724 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01636, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01636 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
# Epoch 00010: loss improved from 0.01608 to 0.01582, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu6
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu7
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0630 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06298, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0214 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06298 to 0.02140, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02140 to 0.01765, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01765 to 0.01724, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01724 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01636, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01636 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01582, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu7
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu0
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu8
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0630 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06298, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0213 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06298 to 0.02133, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02133 to 0.01765, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01765 to 0.01724, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01724 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01636, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01636 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01582, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu8
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu9
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0622 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06220, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0210 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06220 to 0.02096, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02096 to 0.01763, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0173 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01763 to 0.01726, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0170 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01726 to 0.01695, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0167 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01695 to 0.01666, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01666 to 0.01638, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01638 to 0.01611, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01611 to 0.01584, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu9
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu10
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0628 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06280, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0213 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06280 to 0.02132, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02132 to 0.01764, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01764 to 0.01723, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01723 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01663, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01663 to 0.01635, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01635 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01581, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu10
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu11
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0630 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06298, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0214 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06298 to 0.02140, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02140 to 0.01765, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01765 to 0.01724, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
# Epoch 00006: loss improved from 0.01724 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01636, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01636 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01582, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu11
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu3
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu12
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0628 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06280, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0213 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06280 to 0.02125, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02125 to 0.01763, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01763 to 0.01723, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01723 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01635, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01635 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01582, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu12
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu13
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0628 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06280, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0213 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06280 to 0.02125, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02125 to 0.01763, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01763 to 0.01723, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01723 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01635, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01635 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01582, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu13
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu14
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0630 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06298, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0213 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06298 to 0.02133, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02133 to 0.01765, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01765 to 0.01724, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01724 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01636, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01636 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01582, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu14
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu15
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0628 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06280, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0213 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06280 to 0.02132, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02132 to 0.01764, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01764 to 0.01723, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01723 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01663, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01663 to 0.01635, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01635 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01581, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu15
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time1/individu5
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu16
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0630 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06298, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0214 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06298 to 0.02140, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02140 to 0.01765, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01765 to 0.01724, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01724 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01636, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01636 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01582, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu16
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu17
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0622 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06220, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0210 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06220 to 0.02096, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02096 to 0.01763, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0173 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01763 to 0.01726, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0170 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01726 to 0.01695, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0167 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01695 to 0.01666, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01666 to 0.01638, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01638 to 0.01611, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01611 to 0.01584, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu17
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu18
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0630 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06298, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0214 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06298 to 0.02140, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02140 to 0.01765, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0172 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01765 to 0.01724, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0169 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01724 to 0.01693, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0166 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01693 to 0.01664, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01664 to 0.01636, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01636 to 0.01608, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01608 to 0.01582, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu18
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu19
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 23], [1, 25], [2, 32], [0, 11]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.4318 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.43178, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.0624 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.43178 to 0.06239, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.0210 - acc: 0.0011
#
# Epoch 00003: loss improved from 0.06239 to 0.02104, saving model to BestWeights.hdf5
# Epoch 4/10
#  - 0s - loss: 0.0176 - acc: 0.0011
#
# Epoch 00004: loss improved from 0.02104 to 0.01764, saving model to BestWeights.hdf5
# Epoch 5/10
#  - 0s - loss: 0.0173 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.01764 to 0.01726, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.0170 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.01726 to 0.01696, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0167 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.01696 to 0.01667, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0164 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.01667 to 0.01638, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0161 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.01638 to 0.01611, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0158 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.01611 to 0.01584, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu19
# Note = 21.373274631523262
# Note = 21.208134507989534
# Note = 21.30041178690481
# Note = 21.42238709132219
# Note = 60.96898317503832
# Note = 60.969184512198304
# Note = 61.02233360751749
# Note = 61.02245805024018
# Note = 61.02687903934931
# Note = 60.813830638081896
# Note = 60.969195811049964
# Note = 61.02235829205993
# Note = 60.9735890146857
# Note = 60.97361549352376
# Note = 61.02680253210142
# Note = 60.969209793057175
# Note = 61.022426641784534
# Note = 60.81372600833444
# Note = 61.02237143461279
# Note = 60.86765861507186
# lim= 8
# ListOnote= [21.373274631523262, 21.208134507989534, 21.30041178690481, 21.42238709132219, 60.96898317503832, 60.969184512198304, 61.02233360751749, 61.02245805024018, 61.02687903934931, 60.813830638081896, 60.969195811049964, 61.02235829205993, 60.9735890146857, 60.97361549352376, 61.02680253210142, 60.969209793057175, 61.022426641784534, 60.81372600833444, 61.02237143461279, 60.86765861507186]
# bestNoteIndexlist= [ 1  2  0  3 17  9 19  4]
# worstNoteIndexlist= [ 5 10 15 12 13  6 11 18 16  7 14  8]
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu5
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu10
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu15
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu12
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu13
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu6
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu11
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu18
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu16
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu7
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu14
# killing : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu8
# created :  /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time3
# loadInvidualModel :IndividuPath= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time2/individu1
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time3/individu0
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 36], [1, 30], [2, 34], [0, 12]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
#  - 1s - loss: 0.1870 - acc: 0.0011
#
# Epoch 00001: loss improved from inf to 0.18704, saving model to BestWeights.hdf5
# Epoch 2/10
#  - 0s - loss: 0.1729 - acc: 0.0011
#
# Epoch 00002: loss improved from 0.18704 to 0.17288, saving model to BestWeights.hdf5
# Epoch 3/10
#  - 0s - loss: 0.1838 - acc: 0.0011
#
# Epoch 00003: loss did not improve from 0.17288
# Epoch 4/10
#  - 0s - loss: 0.2118 - acc: 0.0000e+00
#
# Epoch 00004: loss did not improve from 0.17288
# Epoch 5/10
#  - 0s - loss: 0.1685 - acc: 0.0011
#
# Epoch 00005: loss improved from 0.17288 to 0.16853, saving model to BestWeights.hdf5
# Epoch 6/10
#  - 0s - loss: 0.1212 - acc: 0.0011
#
# Epoch 00006: loss improved from 0.16853 to 0.12120, saving model to BestWeights.hdf5
# Epoch 7/10
#  - 0s - loss: 0.0708 - acc: 0.0011
#
# Epoch 00007: loss improved from 0.12120 to 0.07084, saving model to BestWeights.hdf5
# Epoch 8/10
#  - 0s - loss: 0.0529 - acc: 0.0011
#
# Epoch 00008: loss improved from 0.07084 to 0.05293, saving model to BestWeights.hdf5
# Epoch 9/10
#  - 0s - loss: 0.0461 - acc: 0.0011
#
# Epoch 00009: loss improved from 0.05293 to 0.04612, saving model to BestWeights.hdf5
# Epoch 10/10
#  - 0s - loss: 0.0427 - acc: 0.0011
#
# Epoch 00010: loss improved from 0.04612 to 0.04274, saving model to BestWeights.hdf5
# creating the residus for the boosting
# saveIndividualModel model2 at : /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time3/individu0
# pathCreatechild= /Users/olivier/keras/NeuralPricing/A_YetiPhoenix_VolLoc/New_Simu_Test/loop/time3/individu1
# mutateIndividualModel : adding neurons [13, 5, 2, 1]
# specList= [[0, 36], [1, 30], [2, 34], [0, 12]]
# deltaNbNeuronList= [13, 5, 2, 1]
# convergeIndividualModel :
# Epoch 1/10
